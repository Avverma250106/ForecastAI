# %%
import pandas as pd
from datetime import datetime

# %%
data = [
    ["SKU-101", "2026-02-15", 35, 120.0, "CUST-001", "ORD-1001"],
    ["SKU-101", "2026-02-16", 42, 120.0, "CUST-002", "ORD-1002"],
    ["SKU-102", "2026-02-17", 95, 150.0, "CUST-003", "ORD-1003"],
    ["SKU-101", "2026-02-18", 120, 120.0, "CUST-004", "ORD-1004"],
    ["SKU-103", "2026-02-19", 140, 180.0, "CUST-005", "ORD-1005"],
    ["SKU-102", "2026-02-20", 165, 150.0, "CUST-006", "ORD-1006"],
    ["SKU-101", "2026-02-21", 210, 120.0, "CUST-007", "ORD-1007"],
    ["SKU-104", "2026-02-22", 240, 200.0, "CUST-008", "ORD-1008"],
    ["SKU-103", "2026-02-23", 260, 180.0, "CUST-009", "ORD-1009"],
    ["SKU-102", "2026-02-24", 300, 150.0, "CUST-010", "ORD-1010"],
    ["SKU-101", "2026-02-25", 320, 120.0, "CUST-011", "ORD-1011"],
    ["SKU-104", "2026-02-26", 360, 200.0, "CUST-012", "ORD-1012"],
    ["SKU-105", "2026-02-27", 380, 220.0, "CUST-013", "ORD-1013"],
    ["SKU-101", "2026-02-28", 400, 120.0, "CUST-014", "ORD-1014"],
    ["SKU-104", "2026-03-01", 440, 200.0, "CUST-015", "ORD-1015"],
    ["SKU-103", "2026-03-02", 485, 180.0, "CUST-016", "ORD-1016"],
    ["SKU-105", "2026-03-03", 510, 220.0, "CUST-017", "ORD-1017"],
    ["SKU-102", "2026-03-04", 580, 150.0, "CUST-018", "ORD-1018"],
    ["SKU-101", "2026-03-05", 620, 120.0, "CUST-019", "ORD-1019"],
    ["SKU-104", "2026-03-06", 700, 200.0, "CUST-020", "ORD-1020"],
    ["SKU-105", "2026-03-07", 780, 220.0, "CUST-021", "ORD-1021"],
    ["SKU-103", "2026-03-08", 850, 180.0, "CUST-022", "ORD-1022"],
    ["SKU-102", "2026-03-09", 920, 150.0, "CUST-023", "ORD-1023"],
    ["SKU-101", "2026-03-10", 1000, 120.0, "CUST-024", "ORD-1024"],
    ["SKU-102", "2026-03-11", 950, 150.0, "CUST-025", "ORD-1025"],
    ["SKU-101", "2026-03-12", 1020, 120.0, "CUST-026", "ORD-1026"],
    ["SKU-104", "2026-03-13", 1100, 200.0, "CUST-027", "ORD-1027"],
    ["SKU-105", "2026-03-14", 1180, 220.0, "CUST-028", "ORD-1028"],
    ["SKU-103", "2026-03-15", 1250, 180.0, "CUST-029", "ORD-1029"],
    ["SKU-102", "2026-03-16", 1350, 150.0, "CUST-030", "ORD-1030"],
    ["SKU-101", "2026-03-17", 1500, 120.0, "CUST-031", "ORD-1031"],
    ["SKU-104", "2026-03-18", 1700, 200.0, "CUST-032", "ORD-1032"],
]

# %%
df = pd.DataFrame(
    data,
    columns=["sku", "sale_date", "quantity", "unit_price", "customer_id", "order_id"]
)

df["sale_date"] = pd.to_datetime(df["sale_date"])

# %%
df.to_csv("sales_data.csv", index=False)
